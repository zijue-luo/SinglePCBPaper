# %%
import pickle

with open("fit_results.pkl", "rb") as f:
    data = pickle.load(f)

print(type(data), len(data))
print(data[0].keys())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pickle
#       3 with open("fit_results.pkl", "rb") as f:
# ----> 4     data = pickle.load(f)
#       6 print(type(data), len(data))
#       7 print(data[0].keys())
#
# ModuleNotFoundError: No module named 'scipy.special._special_ufuncs'
